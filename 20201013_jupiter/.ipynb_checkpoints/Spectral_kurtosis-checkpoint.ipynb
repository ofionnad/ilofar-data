# %%
### continue from old messy SK notebook

# %%
######################
##### Imports ######
######################

import numpy as np
import matplotlib.pyplot as plt

import astropy.units as u
from sunpy.time import TimeRange

import pandas as pd
import xarray as xr

from scipy.signal import stft, istft
import scipy.stats as st

# %matplotlib notebook

# %%
######################
##### Functions ######
######################

def sb_to_f(sbs, obs_mode):
    nyq_dict = {3:1, 5:2, 7:3}
    nyq_zone = nyq_dict[obs_mode]
    clock_dict = {3:200, 4:160, 5:200, 6:160, 7:200} #MHz
    clock = clock_dict[obs_mode]
    nu = (nyq_zone-1. + sbs/512.) * (clock/2.)
    return nu * u.MHz

def plot_spectrum_plt(data, freqs):
    plt.imshow(data.T, aspect='auto', origin='lower',
           vmin=np.percentile(data.T, 5), 
           vmax=np.percentile(data.T, 95),
           extent=[0, data.shape[1], min(freqs[30:150]).value, max(freqs[30:150]).value])

def plot_stft_map(stft_i, i):
	"""
	i - particular index corresponding to individual subband stft
	stft_i - value returned from scipy.signal.stft()
			 should be a 3d tuple if passing more than 1 subband to stft()
	"""
	f, ax = plt.subplots(2)
	ax[0].pcolormesh(stft_i[1], stft_i[0], np.abs(stft_i[2][:,i,:]), shading='auto', 
					 vmin=np.percentile(np.abs(sft_i[2][:,i,:]), 2), 
					 vmax=np.percentile(np.abs(sft_i[2][:,i,:]), 98))

def spectral_kurtosis(stft_arr):
	frac_top = np.mean((np.abs(stft_arr)**4), axis=2)
	frac_bottom = np.mean((np.abs(stft_arr)**2), axis=2)**2
	return (frac_top / frac_bottom) - 2.

def sk_threshold(ci, sft_times):
    z = st.norm.ppf(ci)
    return z*(2./np.sqrt(sft_times))

######################

# %%
######################
#### Reading data ####
######################

fname = 'udpoutput/jupiter-stokesI_0_2020-10-13T17:47:00_19563125244140'
sbs = np.arange(76, 320)
obs_mode = 3
trange = TimeRange("2020-10-13T17:47:00", 10.*u.min)
"""
fname = 'udpoutput/jupiter-stokesI_0_2020-10-13T17:47:00_19563125244140'
sbs = np.arange(76, 319)
obs_mode = 3
trange = TimeRange("2020-10-13T17:47:00", 10.*u.minute)
"""

xlabel = "Time"
ylabel = "Frequency (MHz)"
title = "Jupiter - Stokes I"

data = np.memmap(fname, np.float32, mode="c")
data = data.reshape(-1, sbs.shape[0])
data = np.flip(data, axis=1)

times = pd.timedelta_range(start="0 millisecond", periods=data.shape[0], freq='81.92U')
freqs = sb_to_f(sbs, obs_mode)

######################

#You can use xarray or just numpy, depending on the datatype and size/shape
dx = xr.DataArray(data, coords=[np.arange(len(times)),freqs], dims=["Time", "Frequency"])

# %%
# Normalise data (removes frequency dependence)
norms = dx.quantile(0.1, dim="Time")
dxn = dx/norms

# %%
## SK = <STFT>**4 / <STFT**2>**2 - 2.

# Get the Short Time Fourier Transform of each subband (just 3 for now)
dt = dxn[:, [10, 30, 55, 85, 105, 130]]

#from scipy.signal
sft = stft(dt, window='hamming', axis=0, nperseg=564, nfft=2048)

# %%
freqs[[10, 30, 55, 85, 105, 130]]
# Out:
# <Quantity [16.796875 , 20.703125 , 25.5859375, 31.4453125, 35.3515625,
#            40.234375 ] MHz>

# %%
sk = spectral_kurtosis(sft[2])

# %%
sft[2].shape
# Out:
# (1025, 6, 25974)

# %%
sk.shape
# Out:
# (1025, 6)

# %%
f, ax = plt.subplots(nrows=2, ncols=3, figsize=(10, 8))
ax[0,0].plot(sft[0], sk[:,0], c='C0')
ax[0,1].plot(sft[0], sk[:,1], c='C1')
ax[0,2].plot(sft[0], sk[:,2], c='C2')
ax[1,0].plot(sft[0], sk[:,3], c='C3')
ax[1,1].plot(sft[0], sk[:,4], c='C4')
ax[1,2].plot(sft[0], sk[:,5], c='C5')
plt.tight_layout()

# %%
windows = [64, 1024, 2048, 8096]

# %%
dt[:,2].shape
# Out:
# (7324219,)

# %%
sft_s = []
for i in windows:
    sft = stft(dt[:,2], window='hamming', axis=0, nperseg=i, nfft=8096)
    sft_s.append(sft)

# %%
# %time sft = stft(dt[:,2], window='hamming', axis=0, nperseg=512)
# Out:
# CPU times: user 176 ms, sys: 2.48 s, total: 2.66 s
# Wall time: 2.66 s

# %%
sft[2].shape
# Out:
# (257, 28612)

# %%
sft[2].shape
# Out:
# (129, 57222)

# %%
f, ax = plt.subplots(figsize=(8, 8))
# %time ax.pcolormesh(sft[1], sft[0], np.abs(sft[2]), shading='auto', vmin=np.percentile(np.abs(sft[2]), 2),  vmax=np.percentile(np.abs(sft[2]), 98))
# Out:
# CPU times: user 1.15 s, sys: 4.64 s, total: 5.79 s
# Wall time: 5.79 s

# %%
f, ax = plt.subplots(figsize=(8, 8))
# %time ax.imshow(np.abs(sft[2]), aspect='auto', origin='lower', vmin=np.percentile(np.abs(sft[2]), 2), vmax=np.percentile(np.abs(sft[2]), 98))
# Out:
# <img src="data:image/png;base64,..." width="800">
# CPU times: user 564 ms, sys: 1.68 s, total: 2.25 s
# Wall time: 2.25 s

# %%
limit = sk_threshold(0.997, len(sft[1]))
print(limit)
# Out:
# 0.032489128707310896

# %%
sft_mask = np.ma.masked_greater(sft[2], limit)

# %%
f, ax = plt.subplots(figsize=(8, 8))
ax.imshow(np.abs(sft_mask), aspect='auto', origin='lower', 
          vmin=np.percentile(np.abs(sft_mask), 2), 
          vmax=np.percentile(np.abs(sft_mask), 98))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
subband_data_cleaned = istft(sft_mask, window='hamming', nperseg=512)

# %%
f, ax = plt.subplots()
plt.plot(dt[:,2])
plt.plot(subband_data_cleaned)
