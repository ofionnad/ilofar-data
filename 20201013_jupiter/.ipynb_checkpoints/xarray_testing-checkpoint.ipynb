# %%
"""
Trying to get ilofar data in a manageable dask format! 
Keeps ending up slower than just using xarray or pandas or numpy alone.
"""
# Out:
# '\nTrying to get ilofar data in a manageable dask format! \nKeeps ending up slower than just using xarray or pandas or numpy alone.\n'

# %%
from dask.distributed import Client, progress
client = Client(processes=False, threads_per_worker=8,
                n_workers=32, memory_limit='4GB')
client

### ssh -N -f -L localhost:8787:localhost:8787 ofionnad@ucc2 
### run this locally to get it working remotely
### the client seemed to run on 8787 automatically
# Out:
# /home/ofionnad/realta/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# <Client: 'inproc://192.168.1.65/115033/1' processes=32 threads=256, memory=128.00 GB>

# %%
import dask.array as da
import pandas as pd
import numpy as np

import astropy.units as u
from sunpy.time import TimeRange
import matplotlib.dates as mdates
import datetime as dt
# Out:
# /home/ofionnad/realta/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
#### get that data

fname = 'udpoutput/cygA-1s-stokesI-notimedec_0_2020-10-13T17:47:00_ld'
sbs = np.arange(76, 197)
obs_mode = 3
trange = TimeRange("2020-10-13T17:47:00", 1.*u.second)
"""
fname = 'udpoutput/jupiter-stokesI_0_2020-10-13T17:47:00_19563125244140'
sbs = np.arange(76, 319)
obs_mode = 3
trange = TimeRange("2020-10-13T17:47:00", 10.*u.minute)
"""
xlabel = "Time"
ylabel = "Frequency (MHz)"
title = "Cyg A - Stokes I"

# %%
def sb_to_f(sbs, obs_mode):
    nyq_dict = {3:1, 5:2, 7:3}
    nyq_zone = nyq_dict[obs_mode]
    clock_dict = {3:200, 4:160, 5:200, 6:160, 7:200} #MHz
    clock = clock_dict[obs_mode]
    nu = (nyq_zone-1. + sbs/512.) * (clock/2.)
    return nu * u.MHz

# %%
dtypes = np.dtype([('freq', 'f4'), ('time', 'f4')])
# %time data = np.fromfile("udpoutput/cygA-1s-stokesI-notimedec_0_2020-10-13T17:47:00_ld")
# Out:
# CPU times: user 0 ns, sys: 364 ms, total: 364 ms
# Wall time: 362 ms

# %%
# %time data = data.reshape(-1, int((len(sbs)+1) / 2))
# %time df = pd.DataFrame(data)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 49.6 µs
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 1.44 ms

# %%
import datashader as ds, pandas as pd
import datashader.transfer_functions as tf
from colorcet import gray, bgy, dimgray
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(figsize=(12, 6))
# %time plt.imshow(df.T, aspect="auto", cmap="cet_dimgray", vmin=np.percentile(df.T, 5), vmax=np.percentile(df.T, 95))
# Out:
# CPU times: user 348 ms, sys: 1.01 s, total: 1.36 s
# Wall time: 1.35 s

# %%
mask_subs = [0, 1, 2, 3, 4, 5, 10, 11, 14, 15, 16, 17, 18, 31, 38, 133, 179] #a list of subbands to mask due to RFI

# %%
fmask = np.ma.array(df.T, mask=False)
fmask.mask[:, mask_subs] = True

# %%
norms = df.mean(axis=0)

# %% [markdown]
# #d_norm = fmask / norms
# fmask.shape

# %%
d_norm = fmask.T.data / norms
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-a6dd01b1285f> in <module>
# ----> 1 d_norm = fmask.T.data / norms
#
# ~/realta/lib/python3.8/site-packages/pandas/core/series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     680
#     681         # for binary ops, use our custom dunder methods
# --> 682         result = ops.maybe_dispatch_ufunc_to_dunder_op(
#     683             self, ufunc, method, *inputs, **kwargs
#     684         )
#
# pandas/_libs/ops_dispatch.pyx in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# ~/realta/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ...

# %%
x = da.random.random((1000000, 3), chunks=(1000, 1000))

# %%
import datashader as ds, pandas as pd
import datashader.transfer_functions as tf

# %%
import dask.dataframe as dd

# %%
type(x)
x = dd.from_array(x, columns=['x_col', 'y_col', 'z_col'])

# %%
type(x)
# Out:
# dask.dataframe.core.DataFrame

# %%
import xarray as xs
# Out:
# /home/ofionnad/realta/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
cvs = ds.Canvas(plot_width=400, plot_height=400)

# %%
agg = cvs.points(x, 'x_col', 'y_col', ds.mean('z_col'))
# Out:
# distributed.worker - WARNING - Worker is at 143% memory usage. Pausing worker.  Process memory: 2.87 GB -- Worker memory limit: 2.00 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 4.78 GB -- Worker memory limit: 2.00 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 4.78 GB -- Worker memory limit: 2.00 GB
# distributed.worker - WARNING - Worker is at 46% memory usage. Resuming worker. Process memory: 927.10 MB -- Worker memory limit: 2.00 GB

# %%
img = tf.shade(agg, cmap=['lightblue', 'darkblue'], how='log')

# %%
img
# Out:
# <xarray.Image (y_col: 400, x_col: 400)>
# array([[4288159513, 4290144339, 4289813064, ..., 4289085491, 4289945420,
#         4290276181],
#        [4290011726, 4290210132, 4290011983, ..., 4290607200, 4289350460,
#         4289349947],
#        [4290209875, 4289482816, 4289349947, ..., 4290342231, 4289879114,
#         4288622887],
#        ...,
#        [4290408281, 4289482302, 4289019442, ..., 4289879114, 4288887085,
#         4289416509],
#        [4289218104, 4290144083, 4289284410, ..., 4290408537, 4289284410,
#         4289416510],
#        [4289350460, 4290210388, 4291996039, ..., 4291069804, 4289945676,
#         4289482559]], dtype=uint32)
# Coordinates:
#   * x_col    (x_col) float64 0.00125 0.00375 0.00625 ... 0.9937 0.9962 0.9987
#   * y_col    (y_col) float64 0.00125 0.00375 0.00625 ... 0.9937 0.9962 0.9987
